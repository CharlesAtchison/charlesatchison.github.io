# %%
import os

# %%
images = os.listdir('images/about_icons')

# %%
for img in images:
    print(f"""<div class="gallery">
    <img src="{img}">
</div>""")
# Out:
# <div class="gallery">
#     <img src="markdown.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="docker.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="python.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="Jekyll.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="tableau.jpeg" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="pandas.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="terminal.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="excel.jpeg" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="spark.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="cicd.png" width="600" height="400">
# </div>
# <div class="gallery">
#     <img src="jquery.png" width="600" height="400">
# </div>
# <div class="gallery">
# ...
