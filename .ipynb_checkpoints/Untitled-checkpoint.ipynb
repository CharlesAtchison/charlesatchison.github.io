# %%
import os

# %%
images = os.listdir('images/about_icons')

# %%
for img in images:
    print(f"""<div class="gallery">
    <img src="/images/about_icons/{img}" width="100" height="100">
</div>""")
# Out:
# <div class="gallery">
#     <img src="/images/about_icons/markdown.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/docker.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/python.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/Jekyll.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/tableau.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/pandas.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/terminal.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/excel.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/spark.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/cicd.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/jquery.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/github.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/jupyter.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/jupyter_lab.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/AWS.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/javascript.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/jinja.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/microsoft.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/matplotlib.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/anaconda.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/airflow.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/numpy.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/scss.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/postgresql.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/apple.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/mysql.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/django.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/seaborn.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/beautiful_soup.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/HTML.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/slack.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/scipy.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/github_pages.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/canva.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/discord.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/pipeline.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/statsmodels.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/scikit_learn.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/kafka.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/vis_studio_code.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/ipython.jpeg" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/mongodb.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/ubuntu.png" width="200" height="200">
# </div>
# <div class="gallery">
#     <img src="/images/about_icons/word.png" width="200" height="200">
# </div>
